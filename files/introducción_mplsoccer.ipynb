# %%
from mplsoccer import Pitch, VerticalPitch
import matplotlib.pyplot as plt

# %%
fig, ax = plt.subplots()

pitch = VerticalPitch(
    pitch_type='custom',
    pitch_length=105,
    pitch_width=68,
    axis=True,
    label=True,
    half=True
)

pitch.draw(ax=ax)
