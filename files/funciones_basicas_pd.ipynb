# %%
import pandas as pd

# %%
df = pd.read_csv('Primera Division Argentina - passing.csv')

# %%
df.sample(5)
# Out:
#      Unnamed: 0         Player passing_Nation passing_Pos      passing_Squad  \
# 440         440   Lucas Janson         ar ARG       MF,FW       Boca Juniors
# 901         901   Lionel Verde              0       MF,DF              Unión
# 769         769  Braian Romero         ar ARG          FW    Vélez Sarsfield
# 780         780    Marco Ruben         ar ARG          FW    Rosario Central
# 584         584    Pablo Monje         ar ARG          MF  Deportivo Riestra
#
#                    passing_Comp passing_Age  passing_Born  passing_90s  \
# 440  Primera Division Argentina      30-050          1994          1.1
# 901  Primera Division Argentina           0             0          0.4
# 769  Primera Division Argentina      33-112          1991         14.2
# 780  Primera Division Argentina      37-345          1986          3.3
# 584  Primera Division Argentina      27-242          1997         14.2
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 928 entries, 0 to 927
# Data columns (total 32 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Unnamed: 0       928 non-null    int64
#  1   Player           928 non-null    object
#  2   passing_Nation   928 non-null    object
#  3   passing_Pos      928 non-null    object
#  4   passing_Squad    928 non-null    object
#  5   passing_Comp     928 non-null    object
#  6   passing_Age      928 non-null    object
#  7   passing_Born     928 non-null    int64
#  8   passing_90s      928 non-null    float64
#  9   passing_Cmp      928 non-null    int64
#  10  passing_Att      928 non-null    int64
#  11  passing_Cmp%     928 non-null    float64
#  12  passing_TotDist  928 non-null    int64
#  13  passing_PrgDist  928 non-null    int64
#  14  passing_Cmp.1    928 non-null    int64
#  15  passing_Att.1    928 non-null    int64
#  16  passing_Cmp%.1   928 non-null    float64
# ...

# %%
list(df.columns)
# Out:
# ['Unnamed: 0',
#  'Player',
#  'passing_Nation',
#  'passing_Pos',
#  'passing_Squad',
#  'passing_Comp',
#  'passing_Age',
#  'passing_Born',
#  'passing_90s',
#  'passing_Cmp',
#  'passing_Att',
#  'passing_Cmp%',
#  'passing_TotDist',
#  'passing_PrgDist',
#  'passing_Cmp.1',
#  'passing_Att.1',
#  'passing_Cmp%.1',
#  'passing_Cmp.2',
#  'passing_Att.2',
#  'passing_Cmp%.2',
#  'passing_Cmp.3',
#  'passing_Att.3',
#  'passing_Cmp%.3',
#  'passing_Ast',
#  'passing_xAG',
#  'passing_xA',
#  'passing_A-xAG',
#  'passing_KP',
#  'passing_1/3',
#  'passing_PPA',
#  'passing_CrsPA',
#  'passing_PrgP']

# %%
df.shape[0]
# Out:
# 928

# %%
df.describe()
# Out:
#        Unnamed: 0  passing_Born  passing_90s  passing_Cmp  passing_Att  \
# count  928.000000    928.000000   928.000000   928.000000   928.000000
# mean   463.500000   1974.190733     5.266595   146.744612   202.418103
# std    268.034824    216.396464     4.548376   150.143608   195.637469
# min      0.000000      0.000000     0.000000     0.000000     0.000000
# 25%    231.750000   1994.000000     1.300000    30.000000    44.000000
# 50%    463.500000   1999.000000     4.050000    93.000000   138.500000
# 75%    695.250000   2002.000000     8.425000   228.250000   319.750000
# max    927.000000   2008.000000    16.000000   906.000000  1049.000000
#
#        passing_Cmp%  passing_TotDist  passing_PrgDist  passing_Cmp.1  \
# count    928.000000       928.000000       928.000000     928.000000
# mean      69.444181      2779.434267      1150.975216      60.299569
# std       13.604375      3039.743129      1501.241174      61.198959
# ...
