# %%
import pandas as pd

# %%
df = pd.read_csv('Primera Division Argentina - passing.csv')

# %%
df[['Player', 'passing_Nation', 'passing_Squad']]
# Out:
#                Player passing_Nation            passing_Squad
# 0       Matías Abaldo         uy URU              Gimnasia–LP
# 1       Lucas Abascia         ar ARG         Cen. Córdoba–SdE
# 2    Luciano Abecasis         ar ARG  Independiente Rivadavia
# 3         Ramón Ábila         ar ARG                  Huracán
# 4      Gonzalo Abrego         ar ARG               Godoy Cruz
# ..                ...            ...                      ...
# 923    Felipe Zenobio         ar ARG                    Tigre
# 924       Kevin Zenon         ar ARG             Boca Juniors
# 925    Bruno Zuculini         ar ARG              Racing Club
# 926    Iker Zufiaurre         ar ARG             Boca Juniors
# 927    Fernando Zuqui         ar ARG              Estudiantes
#
# [928 rows x 3 columns]

# %%
df.index
# Out:
# RangeIndex(start=0, stop=928, step=1)

# %%
df.loc[10, ['Player', 'passing_Nation']]
# Out:
# Player            Marcos Acuña
# passing_Nation          ar ARG
# Name: 10, dtype: object

# %%
df.set_index('Player').loc['Marcos Acuña', 'passing_Pos']
# Out:
# 'DF'

# %%
df
# Out:
#      Unnamed: 0            Player passing_Nation passing_Pos  \
# 0             0     Matías Abaldo         uy URU          FW
# 1             1     Lucas Abascia         ar ARG          DF
# 2             2  Luciano Abecasis         ar ARG          DF
# 3             3       Ramón Ábila         ar ARG          FW
# 4             4    Gonzalo Abrego         ar ARG          MF
# ..          ...               ...            ...         ...
# 923         923    Felipe Zenobio         ar ARG          GK
# 924         924       Kevin Zenon         ar ARG          MF
# 925         925    Bruno Zuculini         ar ARG          MF
# 926         926    Iker Zufiaurre         ar ARG          MF
# 927         927    Fernando Zuqui         ar ARG          MF
#
#                passing_Squad                passing_Comp passing_Age  \
# 0                Gimnasia–LP  Primera Division Argentina      20-185
# 1           Cen. Córdoba–SdE  Primera Division Argentina      28-300
# ...

# %%
df.iloc[10:15, 1:4]
# Out:
#              Player passing_Nation passing_Pos
# 10     Marcos Acuña         ar ARG          DF
# 11  Valentino Acuña         ar ARG          MF
# 12     Walter Acuña         ar ARG       FW,MF
# 13   Luis Advíncula         pe PER          DF
# 14     Alan Aguerre         ar ARG          GK
